# %%
def data_reader(file):
    import json
    import pandas as pd
    my_dict={}
    loaded_json=json.load(open(file))
    doc_list=loaded_json["All questions"]
    for i in range(len(doc_list)):
        my_dict[doc_list[i]['url']]=doc_list[i]['title']+" "+doc_list[i]['description']
    return my_dict,doc_list

def remove_nonwords(text):
    import re
    non_words = re.compile(r"[^a-z']")
    processed_text = re.sub(non_words, ' ', text)
    return processed_text.strip()

def remove_stopwords(text):
    from nltk.corpus import stopwords
    stopwrds=stopwords.words('english')
    words = [word for word in text.split() if word not in stopwrds]
    return words

def stem_words(words):
    from nltk.stem.porter import PorterStemmer
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in words]
    return stemmed_words

def preprocess_text(text):
    processed_text = remove_nonwords(text.lower())
    words = remove_stopwords(processed_text)
    stemmed_words = stem_words(words)
    return stemmed_words

# %%
def corpus_creation(some_dict):
    from collections import Counter
    corpus=[]
    for i in some_dict.keys():
        words=preprocess_text(some_dict[i])
        bag_of_words = Counter(words)
        corpus.append(bag_of_words)
    return corpus

def compute_idf(corpus):
    from collections import defaultdict
    import math
    num_docs = len(corpus)
    idf = defaultdict(lambda: 0)
    for doc in corpus:
        for word in doc.keys():
            idf[word] += 1

    for word, value in idf.items():
        idf[word] = math.log(num_docs / value)
    return idf

def compute_weights(idf,doc):
    x=max(doc.values())
    for word, value in doc.items():
        doc[word] =  (doc[word]/x) * idf[word]
    
        
def normalize(doc):
    import math
    denominator = math.sqrt(sum([e ** 2 for e in doc.values()]))
    for word, value in doc.items():
        doc[word] = value / denominator
        
def build_inverted_index(idf, corpus):
    inverted_index = {}
    for word, value in idf.items():
        inverted_index[word] = {}
        inverted_index[word]['idf'] = value
        inverted_index[word]['postings_list'] = []

    for index, doc in enumerate(corpus):
        for word, value in doc.items():
            inverted_index[word]['postings_list'].append([index, value])

    return inverted_index

def query_preprocess(text,inverted_index):
    from collections import Counter
    words_dictionary=set(inverted_index.keys())
    query=preprocess_text(text)
    query = [word for word in query if word in words_dictionary]
    query = Counter(query)
    return query

# %%
def english_dictionaries():
    import nltk
    from nltk.corpus import words
    word_list = words.words()
    english_dictionary={}
    set_dictio=set([])
    group_words={}
    num_dictionary={}
    for word in word_list:
        english_dictionary[word.lower()]=word.lower()
        num_dictionary[word]=len(word)
    for word in word_list:
        set_dictio.add(num_dictionary[word])
    for i in set_dictio:
        group=[]
        for word in word_list:
            if(int(i)==len(word)):
                group.append(word.lower())
        group_words[i]=group
    return english_dictionary,group_words

def minimum_distance_words(similar_words,word_to_check):
    from Levenshtein import distance
    distances=set([])
    check={}
    results=[]
    for i,j in enumerate(similar_words):
        edit_dist=distance(word_to_check,j)
        check[j]=edit_dist
        distances.add(edit_dist)
    for key in check.keys():
        if(check[key]==min(distances)):
            results.append(key)
    return results

def auto_correct2(word,english_dict,word_groups):
    preprocess_L=[]
    words_to_check=[]
    for i in range(len(word)-1,len(word)+2):
        preprocess_L.extend(word_groups[str(i)])#str()
    for checkword in preprocess_L:
        if(word[0]==checkword[0]):
            words_to_check.append(checkword)
    results=minimum_distance_words(words_to_check,word)
    if len(results)>1:
        print(results)
        print("Something is wrong with your input!")
        final_result=int(input("Please choose the index of one of the recomended words from the list or enter 0 to return the original word :"))
        if(final_result==0):
            return word
        else:
            return results[final_result-1]
    elif(len(results)==0):
        return word
    return results[0]

def check_string(my_string,english_dict,word_groups):
    my_string=remove_nonwords(my_string)
    results=[]
    for item in my_string.split():
        try:
            x=english_dict[item.lower()]
        except:
            x=auto_correct2(item.lower(),english_dict,word_groups)
        results.append(x)
    final=" ".join(results)
    return final

# %%
from gensim.models import Word2Vec
model = Word2Vec.load(r"C:\Users\Nikos\Downloads\Precision Recall\Precision Recall\word2vec trainer\model.model")

# %%
def main_1(path):
    data,docs=data_reader(path)
    corpus=corpus_creation(data)
    idf=compute_idf(corpus)
    for doc in corpus:
        compute_weights(idf, doc)
        normalize(doc)
    inverted_index = build_inverted_index(idf, corpus)
    return inverted_index,data,docs

def main_2(inverted_index,data,docs):
    import math    
    import json

    #english_dict,word_groups=english_dictionaries()
    a_file = open(r"C:\Users\Nikos\Downloads\Precision Recall\Precision Recall\AutoCorrect\english_dictionary.json", "r")
    english_dict = json.load(a_file)
    b_file = open(r"C:\Users\Nikos\Downloads\Precision Recall\Precision Recall\AutoCorrect\group_words.json", "r")
    word_groups = json.load(b_file)

    

    query=input("Give Query: ")

    final_string=check_string(query,english_dict,word_groups)
    print(final_string)
    processed_q=query_preprocess(final_string,inverted_index)
    
    

    L=[]
    for i in processed_q.keys():
        x=model.wv.most_similar(i)
        
        L.append(x[0][0])
    
    F=' '.join(L)
    

    x=max(processed_q.values())

    for word, value in processed_q.items():
        processed_q[word] = inverted_index[word]['idf'] * ((processed_q[word]/x) )
    normalize(processed_q)


    scores = [[i, 0] for i in range(len(data))]
    for word, value in processed_q.items():
        for doc in inverted_index[word]['postings_list']:
            index, weight = doc
            scores[index][1] += value * weight

    scores.sort(key=lambda doc: doc[1], reverse=True)
    sum=0
    
    for i in scores:
        sum+=i[1]
    thresh=sum/len(scores)
    #final_res=[list(i[0],i[1]) for i in scores if i[1]>=thresh]
    final_res=[]
    for i in scores:
        if(i[1]>=thresh):
            final_res.append([i[0],i[1]])
    
    print('----- Results ------ ')
    k=0
    for index,score in enumerate(final_res):
        print('{}. {} - {}'.format(index + 1, docs[score[0]]["url"], score[1]))
        if k>5:
            break
        k=k+1   
    return final_res,docs,list(processed_q.keys()),query,F

# %%
def main_3(items,inverted_index,data,docs):

    processed_q=query_preprocess(items,inverted_index)
    x=max(processed_q.values())

    for word, value in processed_q.items():
        processed_q[word] = inverted_index[word]['idf'] * ((processed_q[word]/x) )
    normalize(processed_q)


    scores = [[i, 0] for i in range(len(data))]
    for word, value in processed_q.items():
        for doc in inverted_index[word]['postings_list']:
            index, weight = doc
            scores[index][1] += value * weight

    scores.sort(key=lambda doc: doc[1], reverse=True)
    sum=0
    
    for i in scores:
        sum+=i[1]
    thresh=sum/len(scores)
    #final_res=[list(i[0],i[1]) for i in scores if i[1]>=thresh]
    final_res=[]
    for i in scores:
        if(i[1]>=thresh):
            final_res.append([i[0],i[1]])
    
    print('----- Expanded Results ------ ')
    k=0
    for index,score in enumerate(final_res):
        print('{}. {} - {}'.format(index + 1, docs[score[0]]["url"], score[1]))
        if k==2:
            break
        k=k+1

# %%
path=r"C:\Users\Nikos\Downloads\Precision Recall\Precision Recall\sample_100_without_duplicates.json"
inv_indx,data,docs=main_1(path)

# %%
results,documents,process_q,query,F=main_2(inv_indx,data,docs)
main_3(F,inv_indx,data,docs)
#results=main_2(inv_indx,data,docs)
# Query1 : nrows alternative for read_sql_table
#Query 2 : incompatible types: JSONLoader cannot be converted to Loader<JSONObject>
#Query3: Laravel eager loading - one to many relation
#Query 4 : python labelling new data points in a histogram
#Query 5: matrices multiplication in mathematica
# Out:
# python histogram
# ----- Results ------
# 1. https:/stackoverflow.com/questions/69550600/python-labelling-new-data-points-in-a-histogram - 0.6966722267970913
# 2. https:/stackoverflow.com/questions/69553283/plotly-express-bar-remove-white-lines - 0.23060353098905728
# 3. https:/stackoverflow.com/questions/69550142/write-data-into-first-column-with-header-perl - 0.2164040893271006
# 4. https:/stackoverflow.com/questions/69553794/python-dump-python-path-configuration-from-command-line - 0.16181521160329218
# 5. https:/stackoverflow.com/questions/69551569/in-pyplot-hist2d-with-customized-colorbar-mark-bins-outside-colorbar-range - 0.1525217016110567
# 6. https:/stackoverflow.com/questions/69551564/python-get-path-to-actual-python-executable - 0.14158915756057172
# 7. https:/stackoverflow.com/questions/69549632/how-to-define-method-in-python-that-takes-the-class-type-as-a-parameter - 0.12589873478879887
# 8. https:/stackoverflow.com/questions/69548769/plot-imputed-ordered-categorical-data - 0.12112096159606332
# 9. https:/stackoverflow.com/questions/69550853/cant-run-tensorflow-on-ubuntu-16-04-using-python-2-7 - 0.11899595861798236
# 10. https:/stackoverflow.com/questions/69549110/how-to-merge-multi-array-of-object-in-python - 0.11710243170191122
# 11. https:/stackoverflow.com/questions/69552140/how-to-store-a-tensorflow-model-in-python-as-a-string-instead-of-frozen-pb-file - 0.11027690026185398
# 12. https:/stackoverflow.com/questions/69549320/using-python-i-have-to-make-a-webhook-for-an-api-to-my-python-script-file - 0.10969454074425272
# 13. https:/stackoverflow.com/questions/69547608/how-to-fix-or-balance-the-image-with-an-white-color-overlay - 0.10258082115704119
# 14. https:/stackoverflow.com/questions/69551541/vscode-report-exception-when-debugging-script-that-import-requests-module-under - 0.10049583363662397
# 15. https:/stackoverflow.com/questions/69548837/how-to-add-a-fixed-key-for-each-element-of-list-in-python - 0.10041968650559596
# 16. https:/stackoverflow.com/questions/69548378/implementing-decorators-in-a-python-c-c-extension-that-can-wrap-decorate-funct - 0.09973371386198318
# 17. https:/stackoverflow.com/questions/69548130/pyc-to-py-decompile-using-python-decompile3-attributeerror-module - 0.09365265549778161
# 18. https:/stackoverflow.com/questions/69553749/python-count-words-in-excel - 0.09327297598162863
# 19. https:/stackoverflow.com/questions/69551000/difficult-case-with-typeerror-only-size-1-arrays-can-be-converted-to-python-sca - 0.09126350001151605
# 20. https:/stackoverflow.com/questions/69549768/how-to-find-out-the-height-of-the-table-from-image-in-python - 0.09101084830646881
# 21. https:/stackoverflow.com/questions/69551838/problem-by-starting-a-python-code-using-systemd - 0.09094695000025599
# 22. https:/stackoverflow.com/questions/69553453/how-to-retrieve-file-object-in-python-sent-via-postman-without-any-url - 0.09023854762257576
# 23. https:/stackoverflow.com/questions/69552876/python-script-for-publishing-sns-message-to-email - 0.09006408588635165
# 24. https:/stackoverflow.com/questions/69548374/how-to-convert-1-character-as-a-string-in-python - 0.08627052586715893
# 25. https:/stackoverflow.com/questions/69551547/how-to-find-search-input-element-with-selenium-using-python - 0.08544452503941008
# 26. https:/stackoverflow.com/questions/69553596/python-count-markers-in-a-buffer - 0.08406056730166311
# 27. https:/stackoverflow.com/questions/69552552/xming-and-ubuntu-18-04-not-displaying-plots-properly - 0.08289809427028651
# 28. https:/stackoverflow.com/questions/69547955/what-is-wrong-with-this-conversion-from-curl-to-python-requests - 0.08078191346400436
# 29. https:/stackoverflow.com/questions/69550801/how-to-run-a-multiple-command-in-a-whole-python-script-to-automatically-open-win - 0.08070958781998497
# 30. https:/stackoverflow.com/questions/69548242/python-local-package - 0.08025949903237181
# 31. https:/stackoverflow.com/questions/69550051/data-pagination-by-month-in-flask-python - 0.07951649792038422
# 32. https:/stackoverflow.com/questions/69551894/password-validation-with-python-not-working - 0.07707872742455686
# 33. https:/stackoverflow.com/questions/69553767/selenium-python-maxretryerror-pytesseract-image-to-string-inside-for-loop - 0.07701336652512751
# 34. https:/stackoverflow.com/questions/69549638/how-to-know-the-average-transfer-speeds-in-python - 0.07158589989613111
# 35. https:/stackoverflow.com/questions/69548527/why-are-eigenvector-computations-in-matlab-and-python-not-matching - 0.0710809018442448
# 36. https:/stackoverflow.com/questions/69550010/json-error-load-cmnts-json-loadfcomments - 0.07049997130948125
# 37. https:/stackoverflow.com/questions/69549540/how-to-add-values-at-each-marker-point-in-python - 0.06926798965963445
# 38. https:/stackoverflow.com/questions/69553462/running-python-command-pip-list-in-command-line-show-fatal-error - 0.06735447410795471
# 39. https:/stackoverflow.com/questions/69548594/py-to-exe-multiple-errors-and-failing-to-fully-combine-all-into-one-file - 0.06661325382873359
# 40. https:/stackoverflow.com/questions/69549564/how-to-store-code-server-debug-status-and-restore - 0.06605133950805418
# 41. https:/stackoverflow.com/questions/69552460/search-replace-words-beetween-custom-tags-by-asterisks-with-python-regex - 0.06477548635136157
# 42. https:/stackoverflow.com/questions/69549752/0737-am-gmt5-30-on-10-11-2011-how-to-convert-this-string-to-datetime-in-pyth - 0.06326421234986387
# 43. https:/stackoverflow.com/questions/69551008/csv-to-json-convert - 0.0628962672397219
# 44. https:/stackoverflow.com/questions/69553804/read-particular-excel-calendar-in-python - 0.06281160803166948
# 45. https:/stackoverflow.com/questions/69547591/how-do-i-write-every-fbx-file-keyframe-rotation-to-a-text-file-in-python - 0.06263496266397625
# 46. https:/stackoverflow.com/questions/69548599/function-recall-working-in-other-ides-but-not-vs-code - 0.061997248621869755
# 47. https:/stackoverflow.com/questions/69549719/django-core-exceptions-improperlyconfigured-application-labels-arent-unique-d - 0.061966338391066994
# 48. https:/stackoverflow.com/questions/69548014/loading-and-reading-a-json-file-for-a-value-in-python - 0.06117858764625167
# 49. https:/stackoverflow.com/questions/69553538/accessing-minizinc-data-from-python - 0.06111799233705621
# 50. https:/stackoverflow.com/questions/69551793/cant-use-python-packages-in-r - 0.06108750541048232
# 51. https:/stackoverflow.com/questions/69552902/how-to-fix-504-error-caused-by-docker-image-update - 0.06092965442591805
# 52. https:/stackoverflow.com/questions/69552527/why-append-method-in-python-can-not-be-assigned - 0.05907477639830603
# 53. https:/stackoverflow.com/questions/69553921/read-a-string-count-occurances-without-using-loops-in-python - 0.058662366403684274
# 54. https:/stackoverflow.com/questions/69549754/how-to-upgrade-which-python-version-jupyter-notebook-uses-without-multiple-envir - 0.05853476111049418
# 55. https:/stackoverflow.com/questions/69548342/im-trying-to-solve-this-dmoj-problem-within-the-time-need-someone-to-review-my - 0.05743559289352703
# 56. https:/stackoverflow.com/questions/69551691/convert-ram-psutil-virtual-memory-into-gauge-metrics-in-prometheus - 0.05739341221765804
# 57. https:/stackoverflow.com/questions/69548301/python-opencv-implementation-of-tensor-voting-perceptual-grouping - 0.05698775296641321
# 58. https:/stackoverflow.com/questions/69552079/handshake-status-400-bad-request-pythone - 0.05562868686260211
# 59. https:/stackoverflow.com/questions/69547679/get-and-add-where-clause-in-sql-query-python - 0.0551504900272187
# 60. https:/stackoverflow.com/questions/69549347/can-you-automate-one-website-with-another - 0.055007933300534856
# 61. https:/stackoverflow.com/questions/69552503/simulating-a-pandemic-python - 0.05458029701238008
# 62. https:/stackoverflow.com/questions/69549625/python-no-audio-playing-from-any-package - 0.05438961588917587
# 63. https:/stackoverflow.com/questions/69550014/plot-a-graph-using-3-variables - 0.053800978815712976
# 64. https:/stackoverflow.com/questions/69551177/sniffing-https-packets-and-extract-url-python - 0.053568193635501415
# 65. https:/stackoverflow.com/questions/69552109/how-would-i-group-by-columns-with-equivalent-prefix-and-sum-them - 0.05311819596976351
# 66. https:/stackoverflow.com/questions/69549649/bigquerytable-a-pubsub-topic-not-working-in-apache-beam-python-sdk-static-src-t - 0.052771238048346596
# 67. https:/stackoverflow.com/questions/69553444/python-splitting-a-txt-file-and-keep-header - 0.05267891069946957
# 68. https:/stackoverflow.com/questions/69552762/whenever-i-run-my-flask-app-in-python-it-doesnt-give-any-resposnse - 0.05261443164634604
# 69. https:/stackoverflow.com/questions/69553569/convert-a-string-to-a-variable-name-in-python - 0.052492477717547975
# 70. https:/stackoverflow.com/questions/69548312/how-do-i-turn-a-py-file-into-an-application-on-mac - 0.05166493271818136
# 71. https:/stackoverflow.com/questions/69549281/how-to-make-a-list-of-dictionaries-in-python-with-scraping - 0.05142426330884313
# 72. https:/stackoverflow.com/questions/69549394/traceback-most-recent-call-last-file-d-python-play-py-line-29-in-module - 0.05100153791833304
# 73. https:/stackoverflow.com/questions/69552570/is-there-a-way-to-remove-the-python-title-from-the-win10toast-notification - 0.05079529499360881
# 74. https:/stackoverflow.com/questions/69547726/substring-in-string-python - 0.05019490022245957
# 75. https:/stackoverflow.com/questions/69551665/what-is-wrong-with-this-codewritten-in-ursina-python - 0.04964098653347139
# 76. https:/stackoverflow.com/questions/69552881/i-want-to-send-streaming-data-from-a-socket-using-python-to-spark-structured-str - 0.04949233525738649
# 77. https:/stackoverflow.com/questions/69553867/failed-to-execute-py-script-due-to-unhandled-exception-no-module-named-win32tim - 0.04926024259201183
# 78. https:/stackoverflow.com/questions/69547500/i-need-fix-my-codea-bytes-like-object-is-required-not-list-somebody-have-an - 0.04878268956447095
# 79. https:/stackoverflow.com/questions/69549497/i-am-trying-to-connect-to-independentreserve-api-using-google-apps-script - 0.04757407575130753
# 80. https:/stackoverflow.com/questions/69552139/how-to-read-binary-coded-files-in-python - 0.04715633539670141
# 81. https:/stackoverflow.com/questions/69550910/google-cloud-sdk-troubleshoot - 0.04642003283142424
# 82. https:/stackoverflow.com/questions/69551414/called-arcpy-script-doesnt-finish-if-called-from-c-sharp-console-app - 0.04555718749523844
# 83. https:/stackoverflow.com/questions/69549199/discord-python-status-check-for-role - 0.04508382012008142
# 84. https:/stackoverflow.com/questions/69552380/wsgi-url-scheme-http-in-docker-using-nginx - 0.044796975297957974
# 85. https:/stackoverflow.com/questions/69548439/non-overlapping-nodes-in-python - 0.04394592372417733
# 86. https:/stackoverflow.com/questions/69547810/closing-a-pygtk-window-if-the-focus-is-gain-and-after-lost - 0.043696521914417565
# 87. https:/stackoverflow.com/questions/69549181/optional-arguments-in-nested-functions-in-python - 0.043660051028101284
# 88. https:/stackoverflow.com/questions/69549824/i-tried-to-create-multiple-sheets-in-excel-using-python-openpyxl-to-store-differ - 0.0436170180229324
# 89. https:/stackoverflow.com/questions/69552150/error-when-installing-web3-via-pip-on-raspberry-pi-3 - 0.04337945054822556
# 90. https:/stackoverflow.com/questions/69553066/what-should-be-the-ideal-answer-to-the-question-why-there-are-no-pointers-in-pyt - 0.04271140822244067
# 91. https:/stackoverflow.com/questions/69548818/syntaxerror-setting-mqtt-subscription-topics - 0.041632250746072075
# 92. https:/stackoverflow.com/questions/69552344/make-python-continue-if-doesnt-find-html-element - 0.04124766914472708
# 93. https:/stackoverflow.com/questions/69552365/unexpected-performance-degradation-in-unpickled-set-in-python - 0.041129720509442316
# 94. https:/stackoverflow.com/questions/69549127/why-does-the-pop-up-calendar-not-click-into-the-next-month-python-selenium - 0.0403492309768968
# 95. https:/stackoverflow.com/questions/69551784/make-a-dataframe-filter-a-variable-so-i-can-set-it-once-and-re-use - 0.04020049062683369
# 96. https:/stackoverflow.com/questions/69553082/how-do-i-solve-an-almost-tridiagonal-matrix-in-python - 0.039996006196976276
# 97. https:/stackoverflow.com/questions/69547859/writing-unit-tests-for-python-api-rate-limiter-tdd-approach - 0.03971313155028326
# 98. https:/stackoverflow.com/questions/69547891/setup-for-oauth2-with-rsa-sha384 - 0.0396557123118504
# 99. https:/stackoverflow.com/questions/69552809/z3-optimization-issue - 0.03950933477769188
# 100. https:/stackoverflow.com/questions/69548625/constructing-api-request-python-query-parameters-with-datetime - 0.0392026806703298
# 101. https:/stackoverflow.com/questions/69552169/how-does-s3-recognize-file-types - 0.038908360874530395
# 102. https:/stackoverflow.com/questions/69549954/python-plotly-radar-chart-with-style - 0.03872510770640098
# 103. https:/stackoverflow.com/questions/69549227/understanding-the-python-syntax - 0.038702444013700786
# 104. https:/stackoverflow.com/questions/69552194/how-to-use-c-sharp-to-convert-svgs-into-icon-fonts - 0.03844520648162832
# 105. https:/stackoverflow.com/questions/69549569/i-want-get-sum-in-list-except-null-by-for-loop-using-python - 0.038045027912347214
# 106. https:/stackoverflow.com/questions/69551144/python-git-and-git-lab-create-project-and-push-code-commit - 0.03796606446351823
# 107. https:/stackoverflow.com/questions/69553253/kafka-python-consumer-not-reading-the-message-from-topics - 0.03749270861337089
# 108. https:/stackoverflow.com/questions/69548185/get-size-of-web-resource-with-python-requests - 0.03746247636105852
# 109. https:/stackoverflow.com/questions/69548577/why-does-the-which-system-command-give-a-256-code-with-os-system-in-python - 0.037461730173673824
# 110. https:/stackoverflow.com/questions/69549492/is-there-a-technique-whereby-python-can-run-mycode-when-a-class-in-code-that - 0.037276363915139166
# 111. https:/stackoverflow.com/questions/69552874/ocr-reader-image-to-text - 0.037162135256933466
# 112. https:/stackoverflow.com/questions/69550044/pdffilewriter-object-has-no-attribute-seek - 0.037151844130071554
# 113. https:/stackoverflow.com/questions/69547692/python-decimal-rounding-issue - 0.036583251229852155
# 114. https:/stackoverflow.com/questions/69547860/output-parameter-in-stored-procedure-binding-in-python - 0.036500953414219106
# 115. https:/stackoverflow.com/questions/69551159/unable-to-read-outlook-mail-items-using-win32com-when-run-as-exe-build-using-pyi - 0.03637317133414425
# 116. https:/stackoverflow.com/questions/69550649/choosing-items-from-a-list-under-skew-normal-distribution-python-and-scipy - 0.036304549090758795
# 117. https:/stackoverflow.com/questions/69552481/apiai-take-json-answer-keyerror-result - 0.03616887505218199
# 118. https:/stackoverflow.com/questions/69552355/python-divide-and-floor-diffrences - 0.0358126406634862
# 119. https:/stackoverflow.com/questions/69552844/python-writing-to-arduino-via-serial - 0.035704302737845944
# 120. https:/stackoverflow.com/questions/69549466/from-dataframe-to-json - 0.0355882072116843
# 121. https:/stackoverflow.com/questions/69550830/init-fs-encoding-failed-to-get-the-python-codec-of-the-filesystem-encoding - 0.035149987961422074
# 122. https:/stackoverflow.com/questions/69548428/unsupervised-outlier-detection-using-kmeans-by-pyspark - 0.03503021702326486
# 123. https:/stackoverflow.com/questions/69552541/adding-a-new-list-in-json-object-using-python - 0.03484465254172189
# 124. https:/stackoverflow.com/questions/69547618/what-am-i-missing-in-my-approach-to-this-dynamic-programming-problem-leetcode - 0.03470626187220167
# 125. https:/stackoverflow.com/questions/69552507/can-windows-10-standalone-executables-in-python-run-on-windows-11 - 0.03469507516106181
# 126. https:/stackoverflow.com/questions/69552333/python-how-to-get-choosen-date-of-qt-datetimeedit-widget-save-it-in-date-forma - 0.03451970677429451
# 127. https:/stackoverflow.com/questions/69547720/working-with-concurrency-and-boostpython-callbacks - 0.034508376364101895
# 128. https:/stackoverflow.com/questions/69547919/f2py-exe-is-somewhere-but-the-directory-isnt-on-path - 0.034468179070548374
# 129. https:/stackoverflow.com/questions/69552679/how-to-return-io-bufferedreader-through-aws-lambdapython - 0.03443658025262497
# 130. https:/stackoverflow.com/questions/69548407/python-list-problem-why-does-the-function-produce-light-blue-vscode - 0.03440100245006642
# 131. https:/stackoverflow.com/questions/69552290/python-how-to-make-method-that-makes-list-which-named-one-of-the-parameter - 0.03400433233974668
# 132. https:/stackoverflow.com/questions/69548586/application-looking-in-root-for-site-packages-instead-of-virtual-environment - 0.03380784516822475
# 133. https:/stackoverflow.com/questions/69548112/how-to-use-the-cookies-from-the-browser-in-my-program-python - 0.033727451642809145
# 134. https:/stackoverflow.com/questions/69549597/pip-installs-my-package-but-im-not-able-to-import-it-python-3-10 - 0.03320042828714853
# 135. https:/stackoverflow.com/questions/69548815/find-substrings-in-binary-string - 0.03319623672275486
# 136. https:/stackoverflow.com/questions/69553564/why-ffmpeg-stops-at-video-conversion - 0.0329645320340635
# 137. https:/stackoverflow.com/questions/69552887/sqlalchemy-association-objects-how-to-deal-with-them-in-python-code - 0.032958660880506724
# 138. https:/stackoverflow.com/questions/69551804/can-i-convert-pyomo-internal-variable-to-float - 0.03268518906649312
# 139. https:/stackoverflow.com/questions/69553385/cannot-save-file-in-tmp-folder - 0.03258026312740511
# 140. https:/stackoverflow.com/questions/69551828/issue-when-running-code-from-sql-server-agent-azure-storage-blob-module-azur - 0.03247255961244459
# 141. https:/stackoverflow.com/questions/69550290/prevent-code-duplication-in-models-client-server - 0.032451862692051296
# 142. https:/stackoverflow.com/questions/69548083/why-would-a-column-in-my-csv-file-end-up-with-indents-on-some-rows-but-not-other - 0.032443260438205467
# 143. https:/stackoverflow.com/questions/69553930/read-only-shared-memory-across-multiple-programs-in-python - 0.03228447391839922
# 144. https:/stackoverflow.com/questions/69552012/how-to-parse-symnols-operators-like-present-in-html-using-python - 0.03222498130789534
# 145. https:/stackoverflow.com/questions/69553415/pythonic-way-of-composing-function-calls-with-multiple-arguments-inside-classes - 0.032137054781583414
# 146. https:/stackoverflow.com/questions/69553498/python-subprocess-reading-from-stdout-blocks-reading-output-in-real-time - 0.0320123953494273
# 147. https:/stackoverflow.com/questions/69551553/how-to-run-a-program-by-holding-spacebar-key-and-releasing-spacebar-to-stop-the - 0.031899006319272644
# 148. https:/stackoverflow.com/questions/69551269/append-negative-integer-into-a-list-python - 0.0313305197885453
# 149. https:/stackoverflow.com/questions/69551406/getting-keyerror-when-trying-to-assign-data-from-a-dictionary-into-class-and-obj - 0.031104597812038195
# 150. https:/stackoverflow.com/questions/69547796/valueerror-the-future-belongs-to-a-different-loop-than-the-one-specified-as-the - 0.030676704862907255
# 151. https:/stackoverflow.com/questions/69551476/how-to-arrange-5-users-number-in-ascending-or-descending-order-in-python-withou - 0.030579022685005185
# 152. https:/stackoverflow.com/questions/69548042/how-do-i-model-this-linear-programming-problem-in-python - 0.029717907588224582
# 153. https:/stackoverflow.com/questions/69548018/else-statement-is-being-bypassed - 0.02893031087378147
# 154. https:/stackoverflow.com/questions/69548854/what-is-x-identity-token-in-http - 0.02887870361751309
# 155. https:/stackoverflow.com/questions/69551663/z-transform-in-sympy - 0.028867905135511553
# 156. https:/stackoverflow.com/questions/69550715/python-dictionary-infytq - 0.028821474125102966
# 157. https:/stackoverflow.com/questions/69549543/not-able-to-download-the-file-from-websiteusing-selenium-python - 0.028734600950387063
# 158. https:/stackoverflow.com/questions/69549225/wrong-logic-in-while-loop-python - 0.028427195370747196
# 159. https:/stackoverflow.com/questions/69549972/creating-a-simple-experience-points-gaining-and-leveling-up-system-in-a-text-bas - 0.028290933031521314
# 160. https:/stackoverflow.com/questions/69553153/how-to-find-a-element-after-a-search-click-checkbox-in-selenium-python - 0.028018365057522213
# 161. https:/stackoverflow.com/questions/69551524/python-pyspark-match-consecutive-rows-with-similar-name-in-a-column-and-group - 0.02800507275811296
# 162. https:/stackoverflow.com/questions/69552922/need-help-getting-an-error-with-python-expected-an-indented-block - 0.027982808731927412
# 163. https:/stackoverflow.com/questions/69553482/how-to-convert-the-packet-flow-id-object-type-to-inter-type-in-pandas-python-in - 0.0275141383871366
# 164. https:/stackoverflow.com/questions/69551596/how-to-detach-process-in-ubuntu - 0.027435521220282352
# 165. https:/stackoverflow.com/questions/69552402/how-do-you-append-objects-in-a-hash-table-with-the-name-of-the-objects-as-the-ke - 0.027178295705936183
# 166. https:/stackoverflow.com/questions/69553584/stop-aws-ec2-if-no-input-requests-in-fastapi-after-a-specific-time - 0.027070742308457955
# 167. https:/stackoverflow.com/questions/69550197/why-doesnt-matplotlib-plot-this-parametric-curve - 0.027050277959774466
# 168. https:/stackoverflow.com/questions/69547559/minimal-working-press-and-hold-example-in-selenium - 0.026933591399911545
# 169. https:/stackoverflow.com/questions/69550446/hackerrank-python-nested-lists-exercise - 0.026737264829949765
# 170. https:/stackoverflow.com/questions/69547813/sqlite3-python-no-such-table-when-insert-data-after-table-is-created-successfull - 0.026659517344542843
# 171. https:/stackoverflow.com/questions/69553523/fastest-way-to-get-sets-of-all-mutually-exclusive-pairs-that-can-be-formed-from - 0.026510542370387098
# 172. https:/stackoverflow.com/questions/69549886/maintain-same-python-environment-through-different-makefile-goals - 0.026505110494289948
# 173. https:/stackoverflow.com/questions/69550271/how-to-find-the-upper-and-lower-range-for-a-red-and-yellow-colors-in-hsv-colorsp - 0.026454463807065287
# 174. https:/stackoverflow.com/questions/69552835/how-to-replace-missing-value-in-a-dataframe-with-an-equation-in-python - 0.026428666889787684
# 175. https:/stackoverflow.com/questions/69549031/error-while-running-hello-world-flask-server - 0.026170422870647473
# 176. https:/stackoverflow.com/questions/69551007/typeerror-coroutine-object-is-not-subscriptable - 0.026127376660180526
# 177. https:/stackoverflow.com/questions/69548289/importing-svg-into-html - 0.026102068949051406
# 178. https:/stackoverflow.com/questions/69552230/no-logging-on-azure-devops-pipeline - 0.02592380472883253
# 179. https:/stackoverflow.com/questions/69551597/convert-string-representation-of-a-dictionary-which-contains-comma-in-value-in - 0.025867334768777787
# 180. https:/stackoverflow.com/questions/69553487/converting-list-of-strings-into-list-of-callable-functions-in-python - 0.025556867641465288
# 181. https:/stackoverflow.com/questions/69548397/how-to-find-a-sequence-of-numbers-in-a-numpy-array-column - 0.02501726220533718
# 182. https:/stackoverflow.com/questions/69553256/discord-py-attributeerror-nonetype-object-has-no-attribute-id-on-heroku - 0.025006778585552152
# 183. https:/stackoverflow.com/questions/69550019/calling-a-function-twice-but-in-second-time-first-list-which-was-returned-by-th - 0.024982003776852505
# 184. https:/stackoverflow.com/questions/69549935/comparing-image-searching-with-ahk-or-pyautogui - 0.024916773555470454
# 185. https:/stackoverflow.com/questions/69553906/connect-azure-runbook-with-file-share-in-azure-with-python - 0.024759992431000903
# 186. https:/stackoverflow.com/questions/69553141/boxplot-in-python-using-matplotlib-pyplot-and-pandas-from-csv-file - 0.024636609259954013
# 187. https:/stackoverflow.com/questions/69553811/unable-to-make-a-scrollable-table-in-kivy - 0.024247664246168095
# 188. https:/stackoverflow.com/questions/69550396/differect-result-with-replace-method-in-python - 0.024128572877210108
# 189. https:/stackoverflow.com/questions/69551017/raspberry-pi-raspbian-how-to-connect-to-usb-coin-acceptor-emp-800 - 0.024085802825335956
# 190. https:/stackoverflow.com/questions/69548931/mediawiki-extension-syntaxhighlight - 0.024044287164083498
# 191. https:/stackoverflow.com/questions/69553711/stdout-of-range-error-in-sending-an-image-with-sockets - 0.024016428325784607
# 192. https:/stackoverflow.com/questions/69548369/how-to-get-my-server-to-tell-a-client-to-close-connection - 0.02392711464274121
# 193. https:/stackoverflow.com/questions/69549872/create-calculated-field-within-dataset-using-python - 0.023886986338023754
# 194. https:/stackoverflow.com/questions/69549984/how-to-convert-hwp-document-into-html-without-data-loss - 0.02355221864962748
# 195. https:/stackoverflow.com/questions/69553534/nameerror-name-s-is-not-defined-snake-pygame - 0.0233230086739911
# 196. https:/stackoverflow.com/questions/69549361/scraping-data-from-html-with-multiple-elements - 0.02322733821364387
# 197. https:/stackoverflow.com/questions/69550261/how-to-fix-this-elementtree-py1320xml-in-element-tree - 0.023107466407939998
# 198. https:/stackoverflow.com/questions/69548381/recognizing-class-parameters - 0.0229621099294085
# 199. https:/stackoverflow.com/questions/69547760/matplotlib-error-x-and-y-must-have-same-first-dimension-but-have-shapes-100 - 0.02296096632913979
# 200. https:/stackoverflow.com/questions/69549438/how-to-calculate-difference-in-time-of-a-dataset-in-python - 0.02286329041312566
# 201. https:/stackoverflow.com/questions/69551065/setup-with-submodules-dependencies - 0.022725750730601207
# 202. https:/stackoverflow.com/questions/69553717/earning-source-of-developers-of-open-source-technologies - 0.022706910517661667
# 203. https:/stackoverflow.com/questions/69551184/problem-with-filedialog-in-python-selenium-nameerror - 0.02245421430059004
# 204. https:/stackoverflow.com/questions/69549147/mongodb-collection-to-pandas-dataframe - 0.022406647309957246
# 205. https:/stackoverflow.com/questions/69550411/json-decoder-jsondecodeerror-expecting-value-using-python-requests - 0.02232084950476843
# 206. https:/stackoverflow.com/questions/69548736/python-beautifulsoup4-selenium-chromedrivermanager-webpage-crawling-is-not-work - 0.022315977608773383
# 207. https:/stackoverflow.com/questions/69552063/pandas-dataframe-manipulation-and-transformation - 0.022169133970565576
# 208. https:/stackoverflow.com/questions/69550872/how-to-store-the-empty-value-somewhere-in-the-elements-that-do-not-exist-in-pyth - 0.021892573973744098
# 209. https:/stackoverflow.com/questions/69552091/heroku-gunicorn-error-h10-in-python - 0.02176980125829184
# 210. https:/stackoverflow.com/questions/69552306/random-value-from-cloud-datastore - 0.02139690265904852
# 211. https:/stackoverflow.com/questions/69548666/python-ploty-graph-objects-change-y-axis-on-some-subplots-to-percentage - 0.021372454298245566
# 212. https:/stackoverflow.com/questions/69548327/how-to-access-a-method-from-pytest-if-theres-no-explicit-root-package-or-modul - 0.02133090461989873
# 213. https:/stackoverflow.com/questions/69550820/telegram-and-telethon-download-message-and-foto-and-republish - 0.02132078422477182
# 214. https:/stackoverflow.com/questions/69549554/python-loop-over-text-files-and-save-contents-into-list-of-lists-dead-kernel - 0.021124919984132098
# 215. https:/stackoverflow.com/questions/69553519/duplicate-name-in-query-string - 0.021090001592967488
# 216. https:/stackoverflow.com/questions/69547857/python-great-expectations-not-able-to-connect-to-bigquery-instance - 0.021046828685049635
# 217. https:/stackoverflow.com/questions/69553796/break-a-try-loop-in-python - 0.0210355857206659
# 218. https:/stackoverflow.com/questions/69547801/how-can-i-categorize-the-string-values-in-a-column-to-get-correlation-python - 0.020564454398858876
# 219. https:/stackoverflow.com/questions/69548853/is-there-an-alternative-to-using-the-global-keyword - 0.0204340242744929
# 220. https:/stackoverflow.com/questions/69550763/find-alphabet-next-to-repeated-word-in-a-string - 0.02027191985642301
# 221. https:/stackoverflow.com/questions/69553367/object-oriented-programming-unclear-why-the-if-statement-in-a-method-is-not-wo - 0.020146229641960334
# 222. https:/stackoverflow.com/questions/69547914/how-to-programmatically-find-if-the-object-type-is-of-google-protobuf - 0.019967635249912997
# 223. https:/stackoverflow.com/questions/69547557/python-configparser-parse-cfg-files - 0.01983539676511644
# 224. https:/stackoverflow.com/questions/69551124/how-to-add-collision-detection-to-a-python-game-made-using-the-turtle-library - 0.019705243478480284
# 225. https:/stackoverflow.com/questions/69550976/how-to-frame-the-following-json-structure-in-pyspark-with-spark-dataframe - 0.019496176709196653
# 226. https:/stackoverflow.com/questions/69551481/i-added-this-php-script-to-a-site-and-while-it-compiles-and-runs-without-error - 0.019208983612833047
# 227. https:/stackoverflow.com/questions/69553515/how-to-get-reproducible-results-with-keras-tensorflow-on-different-computers - 0.01898140566765929
# 228. https:/stackoverflow.com/questions/69547573/pandas-dataframe-itertuples-boolean-series-groupby-optimization - 0.018955592784197554
# 229. https:/stackoverflow.com/questions/69549913/parse-error-unexpected-element-global-method-security-encountered - 0.01882776131795847
# 230. https:/stackoverflow.com/questions/69553824/ban-any-ip-for-couple-of-minutes-after-certain-attempts - 0.018783912490494433
# 231. https:/stackoverflow.com/questions/69551537/formatting-multidimensional-arrays-with-functions-within-a-list-comprehension-nu - 0.018768748785182112
# 232. https:/stackoverflow.com/questions/69548172/nodemon-vs-node-code-works-in-node-but-not-nodemon - 0.018764889000138386
# 233. https:/stackoverflow.com/questions/69550628/infersent-model-word-importance-in-a-sentence-python3 - 0.018661652129237333
# 234. https:/stackoverflow.com/questions/69551854/how-to-convert-a-this-recursive-program-into-iterative - 0.01848562497446446
# 235. https:/stackoverflow.com/questions/69551776/click-download-button-on-webpage-and-save-file-in-bash-with-shellnium - 0.018344198000225805
# 236. https:/stackoverflow.com/questions/69551937/models-not-getting-registered-to-admin-in-django - 0.018172417631265907
# 237. https:/stackoverflow.com/questions/69549952/assign-values-to-newly-created-column-by-matching-certain-words-in-python - 0.018163903167036703
# 238. https:/stackoverflow.com/questions/69548340/python-subtract-a-number-from-a-list-at-a-specific-position - 0.01813161093009571
# 239. https:/stackoverflow.com/questions/69548270/how-would-a-site-like-w3schools-run-many-languages-locally - 0.017805732861928242
# 240. https:/stackoverflow.com/questions/69549437/combobox-foreground-color-setting-is-lost-when-navigating-out-through-tab-key - 0.017796058471244085
# 241. https:/stackoverflow.com/questions/69551020/trying-to-convert-address-string-to-type-address-in-solidity - 0.01773614781098811
# 242. https:/stackoverflow.com/questions/69548431/dict-object-has-no-attribute-meta-redirect-error - 0.017719369378021196
# 243. https:/stackoverflow.com/questions/69547917/i-am-trying-to-accomplish-a-substring-search-in-python - 0.017236911038788355
# 244. https:/stackoverflow.com/questions/69548029/where-to-see-print-statements-or-find-outputs-generated-in-docker-container - 0.017059922971084905
# 245. https:/stackoverflow.com/questions/69548547/plot-value-counts-grouped-by-multiple-columns-in-python - 0.01689589795842759
# 246. https:/stackoverflow.com/questions/69553454/creating-new-df-after-every-iteration-pandas-python - 0.016833158975929657
# 247. https:/stackoverflow.com/questions/69552238/python-sysv-ipc-create-attach-delete-a-shared-memory - 0.01683118831588137
# 248. https:/stackoverflow.com/questions/69551469/extracting-dominant-color-from-specific-area-of-video-frame-using-opencv-and-pyt - 0.01675447050988947
# 249. https:/stackoverflow.com/questions/69547540/create-a-json-object-and-add-items-in-a-loop-python - 0.016600117146724908
# 250. https:/stackoverflow.com/questions/69551508/attributeerror-module-keras-backend-tensorflow-backend-has-no-attribute-set - 0.016479687170073202
# 251. https:/stackoverflow.com/questions/69549494/a-way-to-make-gpt-3s-davinci-converse-with-a-users-through-a-bot-in-discord - 0.016313352417624414
# 252. https:/stackoverflow.com/questions/69549182/in-python-is-there-a-way-to-check-whether-a-type-of-object-exists-inside-an-arr - 0.016181367137580074
# 253. https:/stackoverflow.com/questions/69548611/facebook-graph-api-get-connections - 0.016174652588654796
# 254. https:/stackoverflow.com/questions/69552567/pip-netrc-file-not-working-for-docker-on-windows-using-wsl-backend - 0.016151129201319142
# 255. https:/stackoverflow.com/questions/69549025/remove-non-numeric-characters-including-numbers-that-form-a-url - 0.01595752270719852
# 256. https:/stackoverflow.com/questions/69553768/converting-a-multi-dimensional-dictionary-which-contains-an-array-of-pandas-data - 0.015784150842358236
# 257. https:/stackoverflow.com/questions/69550009/python-math-pdf-not-generate-correctly - 0.0156308222273723
# 258. https:/stackoverflow.com/questions/69551952/why-is-string-not-being-written-into-tempfile - 0.015314797955768249
# 259. https:/stackoverflow.com/questions/69553288/use-custom-loss-and-custom-training-in-tensorflow2 - 0.0152432940609107
# 260. https:/stackoverflow.com/questions/69552320/scatter-problem-valueerror-c-argument-has-2-elements-which-is-inconsistent - 0.015235621849556196
# 261. https:/stackoverflow.com/questions/69552617/computing-an-fft-to-get-frequency-spectrum-from-wav-file-but-not-seeing-the-ex - 0.015040560541784204
# 262. https:/stackoverflow.com/questions/69550993/python-pass-variable-to-imported-module-at-compilation-time - 0.01489914341104597
# 263. https:/stackoverflow.com/questions/69553639/can-not-plot-off-file-using-plotly-mesh-plots - 0.014542229319601979
# 264. https:/stackoverflow.com/questions/69548675/word-tokenization-takes-too-much-time-to-run - 0.01449908719427083
# 265. https:/stackoverflow.com/questions/69552466/module-pytest-has-no-attribute-allure - 0.014017367575289832
# 266. https:/stackoverflow.com/questions/69549777/how-to-skip-the-urls-without-the-element-in-web-scraping-python - 0.013861391574844164
# 267. https:/stackoverflow.com/questions/69548620/how-to-extract-certain-database-from-minitab-tableu-to-create-a-common-databas - 0.01378114871687015
# 268. https:/stackoverflow.com/questions/69553186/sum-same-dates-on-one-column-each - 0.013772753191055791
# 269. https:/stackoverflow.com/questions/69549747/how-to-make-the-text-file-have-the-same-number-of-whitespaces-in-order-to-make-i - 0.013677016615638905
# 270. https:/stackoverflow.com/questions/69550240/python-pandas-create-1x1-dataframe-containing-a-single-string - 0.01359338055505296
# 271. https:/stackoverflow.com/questions/69552529/how-to-separate-users-input-with-two-separators-and-controlling-the-users-inpu - 0.01352455704878474
# 272. https:/stackoverflow.com/questions/69550967/subtract-blending-mode - 0.013514907947327242
# 273. https:/stackoverflow.com/questions/69547603/parsing-section-of-website-with-playwright-or-requests - 0.013313434013951011
# 274. https:/stackoverflow.com/questions/69550013/how-do-you-find-all-the-recently-modified-files-in-a-directory-using-bash-python - 0.013261718529092767
# 275. https:/stackoverflow.com/questions/69550370/matrix-api-and-google-tts-integration-with-location-tracker-in-android-app - 0.013122502638632785
# 276. https:/stackoverflow.com/questions/69551296/flink-watermarks-not-advancing-in-python-stuck-at-9223372036854775808 - 0.013084420287009488
# 277. https:/stackoverflow.com/questions/69555224/is-there-any-plausible-way-to-block-certain-web-browsers-from-my-website - 0.012879436481725974
# 278. https:/stackoverflow.com/questions/69547647/remove-special-codes-convert-to-normal-u021-u0219 - 0.01260210604261888
# 279. https:/stackoverflow.com/questions/69548516/ansible-task-to-generate-an-aws-ssm-activation-code-with-multiple-tags - 0.012447368045666167
# 280. https:/stackoverflow.com/questions/69552951/google-sheets-how-do-i-sort-a-list-of-members-with-conditions-criteria-int - 0.01244146321461782
# 281. https:/stackoverflow.com/questions/69548074/matplotlib-custom-fonts-in-cloud-functions-using-python-3-9 - 0.012324704463022496
# 282. https:/stackoverflow.com/questions/69547786/cant-install-my-own-pypi-package-requirements-cant-be-satisfied - 0.012127703545680522
# 283. https:/stackoverflow.com/questions/69550353/is-there-a-way-to-manipulate-numbered-paragraphs-in-python-to-remove-certain-par - 0.012032049057503501
# 284. https:/stackoverflow.com/questions/69551066/add-xll-as-addin-to-excel - 0.012027195932097138
# 285. https:/stackoverflow.com/questions/69552599/discord-py-bot-how-to-make-a-bot-respond-to-command-only-in-certain-circumstanc - 0.01184579105100841
# 286. https:/stackoverflow.com/questions/69551429/ways-of-sending-data-between-fastapi-router-methods-endpoints - 0.011342683399013483
# 287. https:/stackoverflow.com/questions/69548080/how-to-directly-control-javascript-mediaelement-library-to-display-only-one-volu - 0.011311344364625307
# 288. https:/stackoverflow.com/questions/69547839/how-to-set-all-pixels-that-are-not-in-the-list-of-allowed-values-to-white - 0.011294588989321636
# 289. https:/stackoverflow.com/questions/69552083/python-associate-two-list-of-points-based-on-distance - 0.011287837068703647
# 290. https:/stackoverflow.com/questions/69548329/is-there-a-python-library-function-that-given-a-string-will-generate-all-permu - 0.011085528575936488
# 291. https:/stackoverflow.com/questions/69552848/how-to-make-a-circular-left-shift-in-a-bitarray-usign-python - 0.011025728991680982
# 292. https:/stackoverflow.com/questions/69548146/store-stdout-and-stderr-logs-of-azure-app-service-into-azure-blob-storage - 0.010998218805649034
# 293. https:/stackoverflow.com/questions/69550060/data-wrangling-in-python-to-create-a-list - 0.010895251093018695
# 294. https:/stackoverflow.com/questions/69550479/low-variance-filter-on-normalized-data - 0.010519144269663303
# 295. https:/stackoverflow.com/questions/69547733/celery-what-pool-should-i-use-for-windows-heavy-cpu-process-and-redis-backend - 0.010234474868345979
# 296. https:/stackoverflow.com/questions/69551121/float-data-type-on-java-not-giving-the-right-value - 0.01018743499729438
# 297. https:/stackoverflow.com/questions/69548410/skew-normal-distribution-skewness-vs-alpha-or-a-parameter-generating-n-integ - 0.009968570476402325
# 298. https:/stackoverflow.com/questions/69547533/pypi-remote-repository-fails-ssl-test - 0.009952947250822634
# 299. https:/stackoverflow.com/questions/69551599/python-converting-multiple-1-page-pdf-to-tif-or-png - 0.009861347833944933
# 300. https:/stackoverflow.com/questions/69551802/undo-goes-to-int-what-shouldnt-have-happened - 0.00942526763974578
# 301. https:/stackoverflow.com/questions/69551261/why-the-singleton-class-take-different-effects-in-multi-processing-and-multi-thr - 0.008910670636033426
# 302. https:/stackoverflow.com/questions/69550553/get-page-id-of-a-confluence-page-from-its-public-url - 0.008609064829666342
# 303. https:/stackoverflow.com/questions/69551655/how-spark-resource-gpu-manager-is-linked-to-physical-resource-availability - 0.008271875930938836
# 304. https:/stackoverflow.com/questions/69548438/vscode-debugger-unable-to-resolve-non-existent-files-while-locally-debugging-aws - 0.007543804881618992
# 305. https:/stackoverflow.com/questions/69548886/python-opengl-vao-how-to-use-separate-arrays-for-vertex-and-color-data - 0.007258571868800036
# 306. https:/stackoverflow.com/questions/69553138/i-made-a-basic-calculator-using-class-and-format-function-in-python-giving-no-er - 0.006837608110695676
# 307. https:/stackoverflow.com/questions/69552594/cannot-install-php5-6-zip-on-ubuntu-16-04 - 0.0064520141468814235
# 308. https:/stackoverflow.com/questions/69548789/python-copy-block-of-text-from-the-line-with-matching-value-to-the-previous-lin - 0.005915256962754181
# 309. https:/stackoverflow.com/questions/69548247/sqlite3-operationalerror-database-is-locked-problem-after-the-last-2-fields-ad - 0.005872175166121155
# 310. https:/stackoverflow.com/questions/69549377/how-to-communicate-with-c-stdout - 0.004656454118703667
# 311. https:/stackoverflow.com/questions/69550545/pandas-pivot-table-percent-of-parent-calculations - 0.004245335762091337
# ----- Expanded Results ------
# 1. https:/stackoverflow.com/questions/69552933/seaborn-distplot-up-to-max-1-density - 0.5922663746897953
# 2. https:/stackoverflow.com/questions/69551547/how-to-find-search-input-element-with-selenium-using-python - 0.33862033996088714
# 3. https:/stackoverflow.com/questions/69547823/how-and-where-to-host-selenium - 0.274355361286823

# %%
import json
file=r"C:\Users\Nikos\Downloads\Precision Recall\Precision Recall\PrecisionRecall\Num_dic_data.json"
loaded_json=json.load(open(file))

# %%
#this is for the query results
num_quer=5
path=r"C:\Users\Nikos\Downloads\Precision Recall\Precision Recall\PrecisionRecall"
labelling1={}
for i in results:
    if any(word in loaded_json[str(i[0])][1] for word in process_q):
        labelling1[i[0]]=str(1)
    else:
        labelling1[i[0]]=str(2)

a_file=open(path+f"\Q{num_quer}_results_labels_Recall.json","w")
a_file=json.dump(labelling1,a_file)

# %%
process_q
# Out:
# ['python', 'histogram']

# %%
#this is for all the data for all data we choose only the most important words from the wuery that we think 
#would actually made the difference to the meaning 
check_q=['matric','mathematica']
labelling2={}
for i in loaded_json:
    if any(word in loaded_json[i][1] for word in check_q):
        labelling2[i]=str(1)
    else:
        labelling2[i]=str(2)

a_file=open(path+f"\Q{num_quer}_all_labels_Recall.json","w")
a_file=json.dump(labelling2,a_file)

# %%
b_file1=open(path+f"\Q{num_quer}_all_labels_Recall.json","r")
all_labels=json.load(b_file1)
len(all_labels)
# Out:
# 3124

# %%
b_file2=open(path+f"\Q{num_quer}_results_labels_Recall.json","r")
results_labels=json.load(b_file2)
len(results_labels)
# Out:
# 311

# %%
def precision(qresults,all_labels):
    #precision=tp/(tp+fp)
    true_pos=[i for i in qresults if (all_labels[str(i)]=='1' and qresults[str(i)]=="1")]
    false_pos=[i for i in qresults if (all_labels[str(i)]=='2' and qresults[str(i)]=="1")]
    return len(true_pos)/(len(true_pos)+len(false_pos))

def recall(qresults,all_labels):
    #recall = tp/(tp+fn)
    true_pos=[i for i in qresults if (all_labels[str(i)]=='1' and qresults[str(i)]=="1")]
    false_neg=[i for i in qresults if (all_labels[str(i)]=='1' and qresults[str(i)]=="2")]
    return len(true_pos)/(len(true_pos)+len(false_neg))

# %%
Q1_precision=precision(results_labels,all_labels)
Q1_Recall=recall(results_labels,all_labels)
F1=2*Q1_precision*Q1_Recall/(Q1_precision+Q1_Recall)
print(f"For Query : {query}")
print(f"Precision = {Q1_precision}, Recall = {Q1_Recall}, F1 = {F1}")
results_dic={"query":query,"Precision":Q1_precision,"Recall":Q1_Recall,"F1":F1}
# Out:
# For Query : python histogram
# Precision = 0.004524886877828055, Recall = 1.0, F1 = 0.00900900900900901

# %%
b_file3=open(path+f"\Q{num_quer}Precision n Recall Results.json","w")
b_file3=json.dump(results_dic,b_file3)

# %%
len(results)
# Out:
# 311
